# %%
from pyspark.sql import Row

paths = [
    "/Volumes/treinamento/bronze/tb_cliente",
    "/Volumes/treinamento/bronze/tb_fornecedor"
]

arquivos = []
for p in paths:
    for f in dbutils.fs.ls(p):
        arquivos.append(Row(path=f.path, size=f.size))

df = spark.createDataFrame(arquivos)
display(df)

# %%
display(dbutils.fs.ls("/Volumes/treinamento/bronze/tb_fornecedor"))

# %%
import pandas as pd
df = pd.read_csv("/Volumes/treinamento/bronze/tb_cliente/Clientes.csv", on_bad_lines='skip')
df.head()

# %%
display(df)

# %% [markdown]
# ## Cria e carrega a Delta Table tb_cliente

# %%
spark_df = spark.createDataFrame(df)
spark_df.write.format("delta").saveAsTable("treinamento.bronze.tb_cliente")

# %% [markdown]
# # Verifica linhas com erro

# %%
with open("/Volumes/treinamento/bronze/tb_cliente/Clientes.csv") as f:
    for i, line in enumerate(f):
        if line.count(',') > 11:  # Esperado 12 colunas → 11 vírgulas
            print(f"Linha {i+1}: {line}")

# %%
# %sql
SELECT * FROM treinamento.bronze.tb_cliente;

# %%
# %sql
describe detail treinamento.bronze.tb_cliente;

# %%
# %sql
insert into treinamento.bronze.tb_cliente (Index,Customer_Id,First_Name,Last_Name,Company,City,Country,Phone_1,Phone_2,Email,Subscription_Date,Website) values (1,'1','Joao','Silva','Joao Silva','Rio de Janeiro','Brazil','11999999999','1188888888','joao.silva@gmail.com','2022-01-01','www.joaosilva.com');

# %%
# %sql
describe history treinamento.bronze.tb_cliente;

# %%
print("Hello World!")
print("Hello World2!")
